# %%
from QAE_module import *
from FCI_MATRIX_helper import *
from STATE_PREP_helper import *

# %%
from dwave.samplers import SimulatedAnnealingSampler
import sys, os
import numpy as np
import dimod
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from IPython.display import display
warnings.filterwarnings("ignore")

# %%
file_path = "C:/Users/prita/Desktop/DIRAC_FCI/DIRAC_SrF_FCI_FF/FCI_min001.txt"
CI_matrix_min001 = read_matrix(file_path)
eignvalues, eignvectors = np.linalg.eigh(CI_matrix_min001)
print(f"Ground state energy: {eignvalues[0]}")

file_path = "C:/Users/prita/Desktop/DIRAC_FCI/DIRAC_SrF_FCI_FF/FCI_max001.txt"
CI_matrix_max001 = read_matrix(file_path)
eignvalues, eignvectors = np.linalg.eigh(CI_matrix_max001)
print(f"Ground state energy: {eignvalues[0]}")
# Out:
# Ground state energy: -1.8912420210189231
# Ground state energy: -1.8866071349243978

# %%
# Convert the numpy array to a pandas DataFrame for better visualization
df_CI_matrix = pd.DataFrame(CI_matrix_min001)
print("CI matrix for lambda -0.001:")
display(df_CI_matrix)
# Out:
# CI matrix for lambda -0.001:
#               0             1             2             3             4   \
# 0  -1.885517e+00  7.439581e-03  3.738766e-08  2.856556e-02  3.404021e-01
# 1   7.404802e-03 -1.767212e+00  5.330761e-07  9.036113e-03 -3.220083e-04
# 2   3.743359e-08  5.827120e-07 -1.765036e+00  4.888347e-08 -7.662443e-11
# 3  -2.379679e-03  9.036113e-03  4.888361e-08 -1.692641e+00  2.241454e-03
# 4   1.711783e-03 -3.220083e-04 -7.662101e-11  2.206675e-03 -1.660493e+00
# 5  -2.930529e-09  2.324547e-09  1.231454e-10  1.484750e-08  2.473192e-07
# 6   3.469818e-05 -1.861052e-03 -1.825700e-10  6.799527e-03 -3.671079e-06
# 7   5.551031e-10  4.287106e-11 -1.937571e-03  4.104511e-08 -1.446494e-09
# 8   7.442686e-04  2.476293e-02  2.183645e-08  4.058482e-02  6.782137e-03
# 9   2.399885e-09  1.313995e-07 -9.027565e-10 -6.270213e-11 -1.533672e-10
# 10  3.039823e-10  2.207544e-09  2.413276e-02 -6.269964e-11  4.168240e-08
# ...

# %%
df_CI_matrix = pd.DataFrame(CI_matrix_max001)
print("CI matrix for lambda 0.001:")
display(df_CI_matrix)
# Out:
# CI matrix for lambda 0.001:
#               0             1             2             3             4   \
# 0  -1.880379e+00  7.753912e-03  2.094283e-08 -2.946280e-02 -3.426335e-01
# 1   7.679026e-03 -1.759051e+00  2.131075e-07 -9.015705e-03  3.244391e-04
# 2   1.934667e-08  2.500200e-07 -1.756885e+00 -2.314545e-08 -4.854322e-10
# 3   2.495373e-03 -9.015705e-03 -2.314548e-08 -1.692059e+00  2.419525e-03
# 4  -2.335821e-03  3.244391e-04 -4.854333e-10  2.344640e-03 -1.657840e+00
# 5  -1.654802e-08 -5.486534e-10 -2.703932e-10  9.056995e-09  1.141737e-07
# 6  -3.544224e-05  1.905804e-03  1.900276e-11  7.122447e-03 -3.764767e-06
# 7   2.759238e-09 -1.690611e-10  1.841703e-03  2.057721e-08 -4.216134e-09
# 8  -7.719207e-04 -2.572594e-02 -9.747159e-09  4.019051e-02  7.085004e-03
# 9  -7.939296e-10 -5.609346e-08  1.568801e-09 -6.664576e-11 -8.629709e-11
# 10  3.170926e-10 -1.653860e-09 -2.458495e-02 -6.664791e-11  2.058068e-08
# ...

# %%
#qae
#Initial parameters for the QAE
#In this case I have chosen the lambda values around HF energy without neucler repulsion energy

lam_min = -2
lam_max = -1.88
K = 10
H = CI_matrix_min001
sampler = SimulatedAnnealingSampler()
reference_ground_state = np.linalg.eigvalsh(H)[0]           
# file_name = "H2_FCI_QAE.txt"                            
scan_data = [[], [], [], []]
output_file_path = 'C:/Users/prita/Desktop/DIRAC_FCI/DIRAC_SrF_FCI_FF/SrF_FCI_QAE_min001.txt'

# %%
with open(output_file_path, 'w') as file:
    file.write('')
for idx, LAM in enumerate(np.linspace(lam_min, lam_max, 200)):
    qubo_energy, qubo_solution = QAE(H, K, LAM, sampler)         
    QA_energies, QA_solutions = [], []
    

    wfn_coeff = get_coefficients(qubo_solution, K)
    energy = compute_energy(H, wfn_coeff)
    energy_functional = compute_energy_functional(H, wfn_coeff, LAM)
    error = abs(energy - reference_ground_state)

    
    with open(output_file_path, 'a') as file:
        file.write("Lambda: {:.5f}, Energy: {:.8f}, Error: {:.2E}, L: {:.8f}\n".format(LAM, energy, error, energy_functional))
    #print("Lambda: {:.5f}, Energy: {:.8f}, L: {:.8f}".format(LAM, energy, energy_functional))
    
    scan_data[0].append(LAM)
    scan_data[1].append(energy)
    scan_data[2].append(error)

min_energy_min001 = min(scan_data[1])
min_error = min(scan_data[2])

print(" Minimum energy from SA: {:.8f}".format(min_energy_min001))
print(" Ground state energy FCI: {:.8f}".format(reference_ground_state))
print(" Minimum error: {:.2E}".format(min_error))
print(" Minimum error percentage: {:.6f}%".format(abs(min_error/reference_ground_state*100)))
# Out:
#  Minimum energy from SA: -1.97634602
#  Ground state energy FCI: -1.89124202
#  Minimum error: 9.63E-04
#  Minimum error percentage: 0.050929%

# %%
#qae
#Initial parameters for the QAE
#In this case I have chosen the lambda values around HF energy without neucler repulsion energy

lam_min = -1.89
lam_max = -1.88
K = 10
H = CI_matrix_max001
sampler = SimulatedAnnealingSampler()
reference_ground_state = np.linalg.eigvalsh(H)[0]           
# file_name = "H2_FCI_QAE.txt"                            
scan_data = [[], [], [], []]
output_file_path = 'C:/Users/prita/Desktop/DIRAC_FCI/DIRAC_SrF_FCI_FF/SrF_FCI_QAE_max001.txt'

# %%
with open(output_file_path, 'w') as file:
    file.write('')
for idx, LAM in enumerate(np.linspace(lam_min, lam_max, 200)):
    qubo_energy, qubo_solution = QAE(H, K, LAM, sampler)         
    QA_energies, QA_solutions = [], []
    

    wfn_coeff = get_coefficients(qubo_solution, K)
    energy = compute_energy(H, wfn_coeff)
    energy_functional = compute_energy_functional(H, wfn_coeff, LAM)
    error = abs(energy - reference_ground_state)

    
    with open(output_file_path, 'a') as file:
        file.write("Lambda: {:.5f}, Energy: {:.8f}, Error: {:.2E}, L: {:.8f}\n".format(LAM, energy, error, energy_functional))
    #print("Lambda: {:.5f}, Energy: {:.8f}, L: {:.8f}".format(LAM, energy, energy_functional))
    
    scan_data[0].append(LAM)
    scan_data[1].append(energy)
    scan_data[2].append(error)

min_energy_max001 = min(scan_data[1])
min_error = min(scan_data[2])

print(" Minimum energy from SA: {:.8f}".format(min_energy_max001))
print(" Ground state energy FCI: {:.8f}".format(reference_ground_state))
print(" Minimum error: {:.2E}".format(min_error))
print(" Minimum error percentage: {:.6f}%".format(abs(min_error/reference_ground_state*100)))
# Out:
#  Minimum energy from SA: -1.93504764
#  Ground state energy FCI: -1.88660713
#  Minimum error: 2.18E-03
#  Minimum error percentage: 0.115690%

# %%
#integral reading after applying perturbation -0.001 
file_path = "C:/Users/prita/Desktop/DIRAC_FF_DATA/DIRAC_FF_DATA/SrF_finitefield_DATA/SrF_FF_0.001/-0.001/FCIDUMP"
# C:\Users\prita\Desktop\DIRAC_FF_DATA\DIRAC_FF_DATA\SrF_finitefield_DATA\SrF_FF_0.001\-0.001\FCIDUMP
integral_dict_min001 = read_integrals(file_path)

#integral reading after applying perturbation +0.001 
file_path = "C:/Users/prita/Desktop/DIRAC_FF_DATA/DIRAC_FF_DATA/SrF_finitefield_DATA/SrF_FF_0.001/+0.001/FCIDUMP"
# C:\Users\prita\Desktop\DIRAC_FF_DATA\DIRAC_FF_DATA\SrF_finitefield_DATA\SrF_FF_0.001\-0.001\FCIDUMP
integral_dict_max001 = read_integrals(file_path)

# %%
print(abs(min_energy_min001 - min_energy_max001))
print(abs(integral_dict_min001["(0, 0, 0, 0)"] - integral_dict_max001["(0, 0, 0, 0)"]))
# Out:
# 0.04129837928213731
# 0.06695553340114202

# %%
del_E = abs(min_energy_min001 + integral_dict_min001["(0, 0, 0, 0)"] - (min_energy_max001 + integral_dict_max001["(0, 0, 0, 0)"]))
print(f"Energy difference between lambda -0.001 and lambda 0.001: {del_E}")
edm_db = del_E/0.002
print(f"Electric dipole moment: {edm_db}")
nuclear_dipole_moment = 35.290635377386
au = 2.54177000
print("PDM: ", abs(edm_db - nuclear_dipole_moment)*au)
# Out:
# Energy difference between lambda -0.001 and lambda 0.001: 0.10825391268326712
# Electric dipole moment: 54.12695634163356
# PDM:  47.87759553729551
